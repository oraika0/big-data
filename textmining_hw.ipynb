# %% [markdown]
# <a href="https://colab.research.google.com/github/oraika0/big-data/blob/master/textmining_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("jiebaR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’

# %%
install.packages("tmcn")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("lubridate")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("stringr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("wordcloud")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("Pwordseg",repos="http://R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “unable to access index for repository http://R-project.org/src/contrib:
#   cannot open URL 'http://R-project.org/src/contrib/PACKAGES'”
# Warning message:
# “package ‘Pwordseg’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
library(dplyr)

# %%
library(lubridate)

# %%
library(stringr)

# %%
library(jiebaR)
# Out:
# Loading required package: jiebaRD

# %%
library(wordcloud)
# Out:
# Loading required package: RColorBrewer

# %%
content <- "憑什麼要失望,藏眼淚到心臟,往事不會說謊別跟它為難,我們兩人之間不需要這樣,我想,修煉愛情的心酸,學會放好以前的渴望,我們那些信仰,要忘記多難,遠距離的欣賞,近距離的迷惘,誰說太陽會找到月亮,別人有的愛,我們不可能模仿,修煉愛情的悲歡,我們這些努力不簡單,快樂煉成淚水,是一種勇敢,幾年前的幻想,幾年後的原諒,為一張臉去養一身傷
別講想念我,我會受不了這樣,記憶它真囂張路燈把痛點亮,情人一起看過多少次月亮,他在天空看過多少次遺忘,多少心慌,修煉愛情的心,學會放好以前的渴望,我們那些信仰,要忘記多難,遠距離的欣賞,近距離的迷惘
誰說太陽會找到月亮,別人有的愛,我們不可能模仿,修煉愛情的悲歡,我們這些努力不簡單,快樂煉成淚水,是一種勇敢,幾年前的幻想,幾年後的原諒,為一張臉去養一身傷,別講想念我,我會受不了這樣,笑著說愛讓人瘋狂,哭著說愛讓人緊張,忘不了那個人就投降,修煉愛情的悲歡,我們這些努力不簡單,快樂煉成淚水,是一種勇敢,幾年前的幻想,幾年後的原諒
為一張臉去養一身傷,別講想念我,我會受不了這樣,幾年前的幻想,幾年後的原諒,為一張臉去養一身傷,別講想念我,我會受不了這樣
"

# %%
cutter <- worker(bylines = F)

# %%
cutter[content]
# Out:
#   [1] "憑"     "什麼"   "要"     "失望"   "藏"     "眼淚"   "到"     "心臟"
#   [9] "往事"   "不會"   "說謊"   "別"     "跟"     "它"     "為"     "難"
#  [17] "我們"   "兩人"   "之間"   "不"     "需要"   "這樣"   "我"     "想"
#  [25] "修煉"   "愛情"   "的"     "心酸"   "學會"   "放好"   "以前"   "的"
#  [33] "渴望"   "我們"   "那些"   "信仰"   "要"     "忘記"   "多難"   "遠距離"
#  [41] "的"     "欣賞"   "近距離" "的"     "迷惘"   "誰"     "說"     "太陽"
#  [49] "會"     "找到"   "月亮"   "別人"   "有"     "的"     "愛"     "我們"
#  [57] "不"     "可能"   "模仿"   "修煉"   "愛情"   "的"     "悲歡"   "我們"
#  [65] "這些"   "努力"   "不"     "簡單"   "快樂"   "煉成"   "淚水"   "是"
#  [73] "一種"   "勇敢"   "幾年"   "前"     "的"     "幻想"   "幾年"   "後"
#  [81] "的"     "原諒"   "為"     "一張"   "臉去"   "養"     "一身"   "傷"
#  [89] "別講"   "想念"   "我"     "我會"   "受不了" "這樣"   "記憶"   "它"
#  [97] "真"     "囂張"   "路燈"   "把"     "痛"     "點亮"   "情人"   "一起"
# [105] "看過"   "多少次" "月亮"   "他"     "在"     "天空"   "看過"   "多少次"
# [113] "遺忘"   "多少"   "心慌"   "修煉"   "愛情"   "的"     "心"     "學會"
# ...

# %%
new_words <- c("遠季離的欣賞","遠距離的迷茫","修練愛情")
for(i in 1:length(new_words)){
 new_user_word(cutter,new_words[i])
}

# %%
content <- str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "憑"     "什麼"   "要"     "失望"   "藏"     "眼淚"   "到"     "心臟"
#   [9] "往事"   "不會"   "說謊"   "別"     "跟"     "它"     "為"     "難"
#  [17] "我們"   "兩人"   "之間"   "不"     "需要"   "這樣"   "想"     "修煉"
#  [25] "愛情"   "心酸"   "學會"   "放好"   "以前"   "渴望"   "我們"   "那些"
#  [33] "信仰"   "要"     "忘記"   "多難"   "遠距離" "欣賞"   "近距離" "迷惘"
#  [41] "誰"     "說"     "太陽"   "會"     "找到"   "月亮"   "別人"   "有"
#  [49] "愛"     "我們"   "不"     "可能"   "模仿"   "修煉"   "愛情"   "悲歡"
#  [57] "我們"   "這些"   "努力"   "不"     "簡單"   "快樂"   "煉成"   "淚水"
#  [65] "是"     "一種"   "勇敢"   "幾年"   "前"     "幻想"   "幾年"   "後"
#  [73] "原諒"   "為"     "一張"   "臉去"   "養"     "一身"   "傷"     "別講"
#  [81] "想念"   "我會"   "受不了" "這樣"   "記憶"   "它"     "真"     "囂張"
#  [89] "路燈"   "把"     "痛"     "點亮"   "情人"   "一起"   "看過"   "多少次"
#  [97] "月亮"   "他"     "在"     "天空"   "看過"   "多少次" "遺忘"   "多少"
# [105] "心慌"   "修煉"   "愛情"   "心"     "學會"   "放好"   "以前"   "渴望"
# [113] "我們"   "那些"   "信仰"   "要"     "忘記"   "多難"   "遠距離" "欣賞"
# ...

# %%
new_words <- c("遠季離的欣賞","遠距離的迷茫","修練愛情")
writeLines(new_words,"new_words.txt")

# %%
stop_words <- c("我","之","更","個","未","而","也","與","的","就")
writeLines(stop_words,"stop_words.txt")

# %%
cutter <- worker(user ="new_words.txt",stop_word = "stop_words.txt",
bylines = FALSE)
seg_words <- cutter[content]
seg_words
# Out:
#   [1] "憑"     "什麼"   "要"     "失望"   "藏"     "眼淚"   "到"     "心臟"
#   [9] "往事"   "不會"   "說謊"   "別"     "跟"     "它"     "為"     "難"
#  [17] "我們"   "兩人"   "之間"   "不"     "需要"   "這樣"   "想"     "修煉"
#  [25] "愛情"   "心酸"   "學會"   "放好"   "以前"   "渴望"   "我們"   "那些"
#  [33] "信仰"   "要"     "忘記"   "多難"   "遠距離" "欣賞"   "近距離" "迷惘"
#  [41] "誰"     "說"     "太陽"   "會"     "找到"   "月亮"   "別人"   "有"
#  [49] "愛"     "我們"   "不"     "可能"   "模仿"   "修煉"   "愛情"   "悲歡"
#  [57] "我們"   "這些"   "努力"   "不"     "簡單"   "快樂"   "煉成"   "淚水"
#  [65] "是"     "一種"   "勇敢"   "幾年"   "前"     "幻想"   "幾年"   "後"
#  [73] "原諒"   "為"     "一張"   "臉去"   "養"     "一身"   "傷"     "別講"
#  [81] "想念"   "我會"   "受不了" "這樣"   "記憶"   "它"     "真"     "囂張"
#  [89] "路燈"   "把"     "痛"     "點亮"   "情人"   "一起"   "看過"   "多少次"
#  [97] "月亮"   "他"     "在"     "天空"   "看過"   "多少次" "遺忘"   "多少"
# [105] "心慌"   "修煉"   "愛情"   "心"     "學會"   "放好"   "以前"   "渴望"
# [113] "我們"   "那些"   "信仰"   "要"     "忘記"   "多難"   "遠距離" "欣賞"
# ...

# %%
txt_freq <- freq(seg_words)

# %%
txt_freq <- arrange(txt_freq,desc(freq))

# %%
head(txt_freq)
# Out:
#   char freq
# 1 幾年 8
# 2 我們 8
# 3 不   6
# 4 愛情 5
# 5 修煉 5
# 6 這樣 5

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(showtext)

# %%
showtext.auto(enable = TRUE)

# %%
par(family=("Microsoft YaHei0"))

# %%
wordcloud(txt_freq$char,txt_freq$freq,min.freq =2,random.order =F,
ordered.colors = F,colors=rainbow(nrow(txt_freq)))
# Out:
# plot without title
