# %% [markdown]
# <a href="https://colab.research.google.com/github/oraika0/big-data/blob/master/1022_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)

# %%
library(ggplot2)

# %%
NBA1314<-fetch_NBAPlayerStatistics("13-14")

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1314)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1314,color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1314,color=ThreesMade)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1314,color=Team)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1314,geom = c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalPoints,data=NBA1314,fill=Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(TotalPoints,data=NBA1314,fill=Team)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,
data=NBA1314,
facets=Position~.)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,
data=NBA1314,
facets=.~Position)
# Out:
# plot without title

# %%
qplot(TotalPoints,data=NBA1314,
facets=Position~.,binwidth=10)
# Out:
# plot without title

# %%
qplot(TotalPoints,data=NBA1314,
facets=Position~.,binwidth=100)
# Out:
# plot without title

# %%
library(ggplot2)

# %%
df<-data.frame(gp=factor(rep(letters[1:3],each=10)),y=rnorm(30))

# %%
ggplot(df,aes(x=gp,y=y))+geom_point()
# Out:
# plot without title

# %%
ggplot(df,aes(x=gp,y=y))+geom_boxplot()
# Out:
# plot without title

# %%
df$z<-df$y+rnorm(30)

# %%
ggplot(df,aes(x=z,y=y))+geom_point()+facet_grid(gp~.)
# Out:
# plot without title

# %%
ggplot(df,aes(x=z,y=y))+geom_point()+facet_grid(.~gp)
# Out:
# plot without title

# %%
ggplot(df,aes(x=z,y=y))+geom_point()+facet_grid(gp~.)+geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df,aes(x=z,y=y))+geom_point()+facet_grid(.~gp)+geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(df,aes(x=z,y=y))+geom_line()+facet_grid(gp~.)
# Out:
# plot without title

# %%
ggplot(df,aes(x=z,y=y,color=gp))+geom_line()
# Out:
# plot without title

# %%
install.packages("data.table")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(datasets)

# %%
library(data.table)

# %%
airquality$Month<-as.factor(airquality$Month)

# %%
airquality.stat<-data.table(airquality)[,.(OzoneMean=mean(Ozone,na.rm=
T),OzoneSD=sd(Ozone,na.rm=T)),by=Month]

# %%
ggplot(data=airquality.stat)+
geom_bar(aes(x=Month,y=OzoneMean),stat="identity")+
geom_errorbar(
  aes(x=Month,ymin=OzoneMean-OzoneSD,ymax=OzoneMean+OzoneSD),width=.1)
# Out:
# plot without title
