# %% [markdown]
# <a href="https://colab.research.google.com/github/oraika0/big-data/blob/master/assessment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(readr)
library(ggplot2)

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext.auto(enable = TRUE)
# Out:
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code

# %%
a <- read.csv("07cb4116c6f0b1cece1a1acf549d223a_export.csv")

# %%
str(a)
# Out:
# 'data.frame':	975 obs. of  8 variables:
#  $ 年底別: chr  "84年" "84年" "84年" "84年" ...
#  $ 年齡別: chr  "總計" "總計" "總計" "未滿15歲" ...
#  $ 性別  : chr  "合計" "男" "女" "合計" ...
#  $ 總計  : int  2632863 1317406 1315457 568120 296876 271244 223628 114285 109343 197212 ...
#  $ 未婚  : int  1315833 695790 620043 568115 296875 271240 222494 114009 108485 184000 ...
#  $ 有偶  : chr  "1151173" "567310" "583863" "5" ...
#  $ 離婚  : chr  "82860" "37941" "44919" "-" ...
#  $ 喪偶  : chr  "82997" "16365" "66632" "-" ...

# %%
ggplot(a,aes(x=年齡別,y=未婚))+geom_point()
# Out:
# plot without title

# %%
ggplot(a,aes(x=離婚))+geom_bar()
# Out:
# plot without title

# %%
qplot(年底別,未婚,data=a)
# Out:
# plot without title

# %%
qplot(年底別,未婚,data=a,color=性別)
# Out:
# plot without title

# %%
qplot(年底別,未婚,data=a,color=年底別)
# Out:
# plot without title
